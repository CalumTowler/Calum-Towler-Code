# %%
import pandas as pd
import os

os.getcwd()
# Out:
# 'C:\\Notebooks\\Stock_Files'

# %% [markdown]
# # Loading Data

# %%
x = pd.read_csv('MSFT2019-04-26.csv')
# x.head(10)
# x.tail(10)
# print(x.tail(10))
# Out:
#                     date   1. open   2. high   3. low  4. close  5. volume
# 380  2019-04-26 09:40:00  129.7400  129.7400  129.440    129.64     241712
# 381  2019-04-26 09:39:00  129.6750  129.7500  129.630    129.73     104756
# 382  2019-04-26 09:38:00  129.8700  129.8975  129.630    129.68     137436
# 383  2019-04-26 09:37:00  130.0619  130.1600  129.680    129.83     133008
# 384  2019-04-26 09:36:00  129.8300  130.1500  129.780    130.09     151010
# 385  2019-04-26 09:35:00  130.0300  130.0300  129.810    129.83     111833
# 386  2019-04-26 09:34:00  129.9000  130.0500  129.781    130.03     149585
# 387  2019-04-26 09:33:00  130.1050  130.1800  129.805    129.92     232852
# 388  2019-04-26 09:32:00  130.0900  130.5152  130.040    130.13     483303
# 389  2019-04-26 09:31:00  129.8000  130.1000  129.580    130.10    1258594

# %% [markdown]
# # Reading Data

# %%
# x.columns

# x['date'][0:5]

# x[['date','4. close']]

# x.iloc[0:4]

# x.iloc[0,4]

# for index, row in x.iterrows():
#     print(index, row)

# x.loc[x['4. close'] == 130.10]
# Out:
#                     date  1. open  2. high  3. low  4. close  5. volume
# 389  2019-04-26 09:31:00    129.8    130.1  129.58     130.1    1258594

# %% [markdown]
# # Sorting/Describing Data

# %%
# x.sort_values('5. volume', ascending = False)
x['Change'] = x['4. close'] - x['1. open']
# Out:
#                     date   1. open   2. high    3. low  4. close  5. volume  \
# 0    2019-04-26 16:00:00  129.7300  129.9100  129.7150  129.8900     484062
# 1    2019-04-26 15:59:00  129.6900  129.7600  129.6900  129.7300     142100
# 2    2019-04-26 15:58:00  129.6740  129.7200  129.6500  129.6900     152430
# 3    2019-04-26 15:57:00  129.6800  129.7000  129.6100  129.6700     180722
# 4    2019-04-26 15:56:00  129.6800  129.8700  129.6800  129.6850     276341
# 5    2019-04-26 15:55:00  129.6050  129.7000  129.5900  129.6800     122666
# 6    2019-04-26 15:54:00  129.5900  129.6200  129.5700  129.6000      68046
# 7    2019-04-26 15:53:00  129.6400  129.6400  129.5900  129.5900      69192
# 8    2019-04-26 15:52:00  129.6500  129.6500  129.6000  129.6400      77548
# 9    2019-04-26 15:51:00  129.6309  129.6700  129.5950  129.6484      78221
# 10   2019-04-26 15:50:00  129.7150  129.7300  129.6357  129.6357      55994
# ...
